# %%
import numpy as np
import pandas as pd
# 方便大家操作，将月份和参选人以及所在政党进行定义：
months = {"JAN" : 1, "FEB" : 2, "MAR" : 3, "APR" : 4, "MAY" : 5, "JUN" : 6, "JUL" : 7, "AUG" : 8, "SEP" : 9, "OCT": 10, "NOV": 11, "DEC" : 12}
of_interest = ["Obama, Barack", "Romney, Mitt", "Santorum, Rick", "Paul, Ron", "Gingrich, Newt"]
parties = {
  "Bachmann, Michelle": "Republican",
  "Romney, Mitt": "Republican",
  "Obama, Barack": "Democrat",
  "Roemer, Charles E. 'Buddy' III": "Reform",
  "Pawlenty, Timothy": "Republican",
  "Johnson, Gary Earl": "Libertarian",
  "Paul, Ron": "Republican",
  "Santorum, Rick": "Republican",
  "Cain, Herman": "Republican",
  "Gingrich, Newt": "Republican",
  "McCotter, Thaddeus G": "Republican",
  "Huntsman, Jon": "Republican",
  "Perry, Rick": "Republican"           
 }

# %% [markdown]
# ### 需求
# - 加载数据
# - 查看数据的基本信息
# - 指定数据截取，将如下字段的数据进行提取，其他数据舍弃
#     - cand_nm ：候选人姓名
#     - contbr_nm ： 捐赠人姓名
#     - contbr_st ：捐赠人所在州
#     - contbr_employer ： 捐赠人所在公司
#     - contbr_occupation ： 捐赠人职业
#     - contb_receipt_amt ：捐赠数额（美元）
#     - contb_receipt_dt ： 捐款的日期
# - 对新数据进行总览,查看是否存在缺失数据
# - 用统计学指标快速描述数值型属性的概要。
# - 空值处理。可能因为忘记填写或者保密等等原因，相关字段出现了空值，将其填充为NOT PROVIDE
# - 异常值处理。将捐款金额<=0的数据删除
# - 新建一列为各个候选人所在党派party
# - 查看party这一列中有哪些不同的元素
# - 统计party列中各个元素出现次数
# - 查看各个党派收到的政治献金总数contb_receipt_amt
# - 查看具体每天各个党派收到的政治献金总数contb_receipt_amt
# - 将表中日期格式转换为'yyyy-mm-dd'。
# - 查看老兵(捐献者职业)DISABLED VETERAN主要支持谁

# %%
df = pd.read_csv('../data/usa_election.txt')
df
# Out:
# /usr/local/conda/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#           cmte_id    cand_id             cand_nm               contbr_nm  \
# 0       C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 1       C00410118  P20002978  Bachmann, Michelle         HARVEY, WILLIAM
# 2       C00410118  P20002978  Bachmann, Michelle           SMITH, LANIER
# 3       C00410118  P20002978  Bachmann, Michelle        BLEVINS, DARONDA
# 4       C00410118  P20002978  Bachmann, Michelle      WARDENBURG, HAROLD
# ...           ...        ...                 ...                     ...
# 536036  C00500587  P20003281         Perry, Rick  ANDERSON, MARILEE MRS.
# 536037  C00500587  P20003281         Perry, Rick      TOLBERT, DARYL MR.
# 536038  C00500587  P20003281         Perry, Rick     GRANE, BRYAN F. MR.
# 536039  C00500587  P20003281         Perry, Rick     DUFFY, DAVID A. MR.
# 536040  C00500587  P20003281         Perry, Rick    GORMAN, CHRIS D. MR.
#
#                contbr_city contbr_st   contbr_zip  \
# 0                   MOBILE        AL  366010290.0
# 1                   MOBILE        AL  366010290.0
# 2                   LANETT        AL  368633403.0
# 3                  PIGGOTT        AR  724548253.0
# 4       HOT SPRINGS NATION        AR  719016467.0
# ...                    ...       ...          ...
# 536036      INFO REQUESTED        XX        99999
# 536037      INFO REQUESTED        XX        99999
# 536038      INFO REQUESTED        XX        99999
# 536039      INFO REQUESTED        XX        99999
# 536040      INFO REQUESTED        XX        99999
#
#                                contbr_employer  \
# 0                                      RETIRED
# 1                                      RETIRED
# 2                        INFORMATION REQUESTED
# 3                                         NONE
# 4                                         NONE
# ...                                        ...
# 536036  INFORMATION REQUESTED PER BEST EFFORTS
# 536037                                T.A.C.C.
# 536038  INFORMATION REQUESTED PER BEST EFFORTS
# 536039            DUFFY EQUIPMENT COMPANY INC.
# 536040  INFORMATION REQUESTED PER BEST EFFORTS
#
#                              contbr_occupation  contb_receipt_amt  \
# 0                                      RETIRED              250.0
# 1                                      RETIRED               50.0
# 2                        INFORMATION REQUESTED              250.0
# 3                                      RETIRED              250.0
# 4                                      RETIRED              300.0
# ...                                        ...                ...
# 536036  INFORMATION REQUESTED PER BEST EFFORTS             2500.0
# 536037            LONGWALL MAINTENANCE FOREMAN              500.0
# 536038  INFORMATION REQUESTED PER BEST EFFORTS              500.0
# 536039                          BUSINESS OWNER             2500.0
# 536040  INFORMATION REQUESTED PER BEST EFFORTS             5000.0
#
#        contb_receipt_dt                                       receipt_desc  \
# 0             20-JUN-11                                                NaN
# 1             23-JUN-11                                                NaN
# 2             05-JUL-11                                                NaN
# 3             01-AUG-11                                                NaN
# 4             20-JUN-11                                                NaN
# ...                 ...                                                ...
# 536036        31-AUG-11                                                NaN
# 536037        30-SEP-11                                                NaN
# 536038        29-SEP-11                                                NaN
# 536039        30-SEP-11                                                NaN
# 536040        29-SEP-11  REATTRIBUTION / REDESIGNATION REQUESTED (AUTOM...
#
#        memo_cd                                          memo_text form_tp  \
# 0          NaN                                                NaN   SA17A
# 1          NaN                                                NaN   SA17A
# 2          NaN                                                NaN   SA17A
# 3          NaN                                                NaN   SA17A
# 4          NaN                                                NaN   SA17A
# ...        ...                                                ...     ...
# 536036     NaN                                                NaN   SA17A
# 536037     NaN                                                NaN   SA17A
# 536038     NaN                                                NaN   SA17A
# 536039     NaN                                                NaN   SA17A
# 536040     NaN  REATTRIBUTION / REDESIGNATION REQUESTED (AUTOM...   SA17A
#
#         file_num
# 0         736166
# 1         736166
# 2         749073
# 3         749073
# 4         736166
# ...          ...
# 536036    751678
# 536037    751678
# 536038    751678
# 536039    751678
# 536040    751678
#
# [536041 rows x 16 columns]

# %%
# 对新数据进行总览,查看是否存在缺失数据
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536041 entries, 0 to 536040
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cmte_id            536041 non-null  object
#  1   cand_id            536041 non-null  object
#  2   cand_nm            536041 non-null  object
#  3   contbr_nm          536041 non-null  object
#  4   contbr_city        536026 non-null  object
#  5   contbr_st          536040 non-null  object
#  6   contbr_zip         535973 non-null  object
#  7   contbr_employer    525088 non-null  object
#  8   contbr_occupation  530520 non-null  object
#  9   contb_receipt_amt  536041 non-null  float64
#  10  contb_receipt_dt   536041 non-null  object
#  11  receipt_desc       8479 non-null    object
#  12  memo_cd            49718 non-null   object
#  13  memo_text          52740 non-null   object
#  14  form_tp            536041 non-null  object
#  15  file_num           536041 non-null  int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 65.4+ MB

# %%
# 用统计学指标快速描述数值型属性的概要
df.describe()
# Out:
#        contb_receipt_amt       file_num
# count       5.360410e+05  536041.000000
# mean        3.750373e+02  761472.107800
# std         3.564436e+03    5148.893508
# min        -3.080000e+04  723511.000000
# 25%         5.000000e+01  756218.000000
# 50%         1.000000e+02  763233.000000
# 75%         2.500000e+02  763621.000000
# max         1.944042e+06  767394.000000

# %%
# 空值处理。可能因为忘记填写或者保密等等原因，相关字段出现了空值，将其填充为NOT PROVIDE
df.fillna("NOT PROVIDE", inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536041 entries, 0 to 536040
# Data columns (total 16 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   cmte_id            536041 non-null  object
#  1   cand_id            536041 non-null  object
#  2   cand_nm            536041 non-null  object
#  3   contbr_nm          536041 non-null  object
#  4   contbr_city        536041 non-null  object
#  5   contbr_st          536041 non-null  object
#  6   contbr_zip         536041 non-null  object
#  7   contbr_employer    536041 non-null  object
#  8   contbr_occupation  536041 non-null  object
#  9   contb_receipt_amt  536041 non-null  float64
#  10  contb_receipt_dt   536041 non-null  object
#  11  receipt_desc       536041 non-null  object
#  12  memo_cd            536041 non-null  object
#  13  memo_text          536041 non-null  object
#  14  form_tp            536041 non-null  object
#  15  file_num           536041 non-null  int64
# dtypes: float64(1), int64(1), object(14)
# memory usage: 65.4+ MB

# %%
# 异常值处理。将捐款金额<=0的数据删除
df["contb_receipt_amt"] <= 0 # 判断哪些值为小于等于0
df.loc[df["contb_receipt_amt"] <= 0] # 捐赠金额小于等于0的行数据
drop_indexs = df.loc[df["contb_receipt_amt"] <= 0].index # 获取这些行的索引
df.drop(labels=drop_indexs, axis=0, inplace=True) # 删除这些行

# %%
# 新建一列为各个候选人所在党派party
df["party"] = df["cand_nm"].map(parties) # 通过cand_name列的值来映射到party列

# %%
df.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL  366010290.0                RETIRED
# 1              MOBILE        AL  366010290.0                RETIRED
# 2              LANETT        AL  368633403.0  INFORMATION REQUESTED
# 3             PIGGOTT        AR  724548253.0                   NONE
# 4  HOT SPRINGS NATION        AR  719016467.0                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED              250.0        20-JUN-11  NOT PROVIDE
# 1                RETIRED               50.0        23-JUN-11  NOT PROVIDE
# 2  INFORMATION REQUESTED              250.0        05-JUL-11  NOT PROVIDE
# 3                RETIRED              250.0        01-AUG-11  NOT PROVIDE
# 4                RETIRED              300.0        20-JUN-11  NOT PROVIDE
#
#        memo_cd    memo_text form_tp  file_num       party
# 0  NOT PROVIDE  NOT PROVIDE   SA17A    736166  Republican
# 1  NOT PROVIDE  NOT PROVIDE   SA17A    736166  Republican
# 2  NOT PROVIDE  NOT PROVIDE   SA17A    749073  Republican
# 3  NOT PROVIDE  NOT PROVIDE   SA17A    749073  Republican
# 4  NOT PROVIDE  NOT PROVIDE   SA17A    736166  Republican

# %%
# 查看party这一列中有哪些不同的元素
df['party'].unique()
# Out:
# array(['Republican', 'Democrat', 'Reform', 'Libertarian'], dtype=object)

# %%
# 统计party列中各个元素出现次数
df["party"].value_counts()
# Out:
# Democrat       289999
# Republican     234300
# Reform           5313
# Libertarian       702
# Name: party, dtype: int64

# %%
# 查看各个党派收到的政治献金总数contb_receipt_amt
df.groupby(by=["contb_receipt_dt", "party"])["contb_receipt_amt"].sum()
# Out:
# contb_receipt_dt  party
# 01-APR-11         Reform             50.00
#                   Republican      12635.00
# 01-AUG-11         Democrat       182198.00
#                   Libertarian      1000.00
#                   Reform           1847.00
#                                    ...
# 31-MAY-11         Republican     313839.80
# 31-OCT-11         Democrat       216971.87
#                   Libertarian      4250.00
#                   Reform           3205.00
#                   Republican     751542.36
# Name: contb_receipt_amt, Length: 1183, dtype: float64

# %%
# 将表中日期格式转换为'yyyy-mm-dd
def trandformDate(date):
    day, month, year = date.split("-")
    month = months[month] # 将英文形式的月份转换成了数字形式的月份
    return '20'+year+'-'+str(month)+'-'+day
df["contb_receipt_dt"] = df["contb_receipt_dt"].map(trandformDate)

# %%
df.head()
# Out:
#      cmte_id    cand_id             cand_nm           contbr_nm  \
# 0  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 1  C00410118  P20002978  Bachmann, Michelle     HARVEY, WILLIAM
# 2  C00410118  P20002978  Bachmann, Michelle       SMITH, LANIER
# 3  C00410118  P20002978  Bachmann, Michelle    BLEVINS, DARONDA
# 4  C00410118  P20002978  Bachmann, Michelle  WARDENBURG, HAROLD
#
#           contbr_city contbr_st   contbr_zip        contbr_employer  \
# 0              MOBILE        AL  366010290.0                RETIRED
# 1              MOBILE        AL  366010290.0                RETIRED
# 2              LANETT        AL  368633403.0  INFORMATION REQUESTED
# 3             PIGGOTT        AR  724548253.0                   NONE
# 4  HOT SPRINGS NATION        AR  719016467.0                   NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 0                RETIRED              250.0        2011-6-20  NOT PROVIDE
# 1                RETIRED               50.0        2011-6-23  NOT PROVIDE
# 2  INFORMATION REQUESTED              250.0        2011-7-05  NOT PROVIDE
# 3                RETIRED              250.0        2011-8-01  NOT PROVIDE
# 4                RETIRED              300.0        2011-6-20  NOT PROVIDE
#
#        memo_cd    memo_text form_tp  file_num       party
# 0  NOT PROVIDE  NOT PROVIDE   SA17A    736166  Republican
# 1  NOT PROVIDE  NOT PROVIDE   SA17A    736166  Republican
# 2  NOT PROVIDE  NOT PROVIDE   SA17A    749073  Republican
# 3  NOT PROVIDE  NOT PROVIDE   SA17A    749073  Republican
# 4  NOT PROVIDE  NOT PROVIDE   SA17A    736166  Republican

# %% [markdown]
# # 查看老兵(捐献者职业)DISABLED VETERAN主要支持谁.给谁捐赠的钱越多表示越支持谁
#
# #可以先将源数据中的老兵这个职业对应的行数据取出
# df['contbr_occupation'] == 'DISABLED VETERAN'
# df_old = df.loc[df['contbr_occupation'] == 'DISABLED VETERAN']
#
# #分组：根据候选人分组，对捐赠金额求和
# df_old.groupby(by='cand_nm')['contb_receipt_amt'].sum()

# %%
df["contbr_occupation"] == "DISABLED VETERAN"
df_old = df.loc[df["contbr_occupation"] == "DISABLED VETERAN"]
df_old
# Out:
#           cmte_id    cand_id         cand_nm                 contbr_nm  \
# 149790  C00431445  P80003338   Obama, Barack            MAHURIN, DAVID
# 150910  C00431445  P80003338   Obama, Barack            MAHURIN, DAVID
# 174041  C00431445  P80003338   Obama, Barack         KRUCHTEN, MICHAEL
# 175244  C00431445  P80003338   Obama, Barack         KRUCHTEN, MICHAEL
# 183790  C00431445  P80003338   Obama, Barack              BRYANT, J.L.
# 184211  C00431445  P80003338   Obama, Barack              BRYANT, J.L.
# 184417  C00431445  P80003338   Obama, Barack              BRYANT, J.L.
# 184761  C00431445  P80003338   Obama, Barack              BRYANT, J.L.
# 185140  C00431445  P80003338   Obama, Barack             BAUER, JOSEPH
# 185264  C00431445  P80003338   Obama, Barack             BAUER, JOSEPH
# 186026  C00431445  P80003338   Obama, Barack             BAUER, JOSEPH
# 186361  C00431445  P80003338   Obama, Barack             BAUER, JOSEPH
# 194750  C00431445  P80003338   Obama, Barack           MCCORMACK, MARK
# 205094  C00431445  P80003338   Obama, Barack         DEKLE, CHARLES R.
# 210809  C00431445  P80003338   Obama, Barack         DEKLE, CHARLES R.
# 210810  C00431445  P80003338   Obama, Barack         DEKLE, CHARLES R.
# 210811  C00431445  P80003338   Obama, Barack         DEKLE, CHARLES R.
# 225948  C00431445  P80003338   Obama, Barack            CAMPBELL, SARA
# 225954  C00431445  P80003338   Obama, Barack            CAMPBELL, SARA
# 231074  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 231773  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 232434  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 233434  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 235014  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 235112  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 235135  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 235846  C00431445  P80003338   Obama, Barack             RORIE, FOREST
# 244060  C00431445  P80003338   Obama, Barack          CARIS, OLIVIA M.
# 260154  C00431445  P80003338   Obama, Barack              NOLAN, DIANA
# 260544  C00431445  P80003338   Obama, Barack              NOLAN, DIANA
# 264154  C00431445  P80003338   Obama, Barack              NOLAN, DIANA
# 289927  C00431445  P80003338   Obama, Barack           ROBERTS, GORDON
# 379163  C00495820  P80000748       Paul, Ron        COMERFORD, CHARLES
# 379537  C00495820  P80000748       Paul, Ron        COMERFORD, CHARLES
# 379555  C00495820  P80000748       Paul, Ron        COMERFORD, CHARLES
# 396211  C00495820  P80000748       Paul, Ron   THORNELL, GARY ENOS MR.
# 408043  C00495820  P80000748       Paul, Ron    BECKER, CHARLES DONALD
# 408743  C00495820  P80000748       Paul, Ron      MCCLAIN, JOHN EDWARD
# 419163  C00495820  P80000748       Paul, Ron      GRANT, MICHAEL JAMES
# 420332  C00495820  P80000748       Paul, Ron       CRAYCRAFT, SETH MR.
# 420517  C00495820  P80000748       Paul, Ron       CRAYCRAFT, SETH MR.
# 421427  C00495820  P80000748       Paul, Ron       CRAYCRAFT, SETH MR.
# 421429  C00495820  P80000748       Paul, Ron        CHAPMAN, ROBERT F.
# 421535  C00495820  P80000748       Paul, Ron       CRAYCRAFT, SETH MR.
# 421621  C00495820  P80000748       Paul, Ron        CHAPMAN, ROBERT F.
# 421741  C00495820  P80000748       Paul, Ron        CHAPMAN, ROBERT F.
# 421754  C00495820  P80000748       Paul, Ron        CHAPMAN, ROBERT F.
# 421839  C00495820  P80000748       Paul, Ron        CHAPMAN, ROBERT F.
# 421895  C00495820  P80000748       Paul, Ron       CRAYCRAFT, SETH MR.
# 429191  C00495820  P80000748       Paul, Ron       ELLIOTT, HEATHER M.
# 430649  C00495820  P80000748       Paul, Ron         HOUSE, ADAM GLENN
# 431049  C00495820  P80000748       Paul, Ron         HOUSE, ADAM GLENN
# 435011  C00495820  P80000748       Paul, Ron      WEAR-CYNFYN, BLEDDYN
# 446880  C00495820  P80000748       Paul, Ron       MANRING, JAMES DEAN
# 453659  C00496034  P20002721  Santorum, Rick  GEIB, JOHN E. MR USA RET
# 453660  C00496034  P20002721  Santorum, Rick  GEIB, JOHN E. MR USA RET
# 453661  C00496034  P20002721  Santorum, Rick  GEIB, JOHN E. MR USA RET
# 459440  C00496067  P00003608    Cain, Herman            MARTIN, SAMUEL
# 459447  C00496067  P00003608    Cain, Herman            MARTIN, SAMUEL
# 464508  C00496067  P00003608    Cain, Herman          ANDERSON, JOSEPH
#
#            contbr_city contbr_st   contbr_zip           contbr_employer  \
# 149790           TAMPA        FL        33616   VETERANS ADMINISTRATION
# 150910           TAMPA        FL        33616   VETERANS ADMINISTRATION
# 174041        ROCKFORD        IL  611146507.0                  DISABLED
# 175244        ROCKFORD        IL  611146507.0                  DISABLED
# 183790          TOPEKA        KS  666121668.0                  RET ARMY
# 184211          TOPEKA        KS  666121668.0                  RET ARMY
# 184417          TOPEKA        KS  666121668.0                  RET ARMY
# 184761          TOPEKA        KS  666121668.0                  RET ARMY
# 185140        PROSPECT        KY      40059.0              NOT EMPLOYED
# 185264        PROSPECT        KY      40059.0              NOT EMPLOYED
# 186026        PROSPECT        KY      40059.0              NOT EMPLOYED
# 186361        PROSPECT        KY      40059.0               NOT PROVIDE
# 194750          BOSTON        MA   21155919.0          DISABLED VETERAN
# 205094  UPPER MARLBORO        MD    207748600                   RETIRED
# 210809  UPPER MARLBORO        MD    207748600                   RETIRED
# 210810  UPPER MARLBORO        MD    207748600                   RETIRED
# 210811  UPPER MARLBORO        MD    207748600                   RETIRED
# 225948     KANSAS CITY        MO    641184568              NOT EMPLOYED
# 225954     KANSAS CITY        MO    641184568              NOT EMPLOYED
# 231074       WADESBORO        NC    281707443                  DISABLED
# 231773       WADESBORO        NC    281707443                  DISABLED
# 232434       WADESBORO        NC    281707443                  DISABLED
# 233434       WADESBORO        NC    281707443                  DISABLED
# 235014       WADESBORO        NC    281707443     INFORMATION REQUESTED
# 235112       WADESBORO        NC    281707443     INFORMATION REQUESTED
# 235135       WADESBORO        NC    281707443     INFORMATION REQUESTED
# 235846       WADESBORO        NC    281707443     INFORMATION REQUESTED
# 244060   MEDFORD LAKES        NJ    080551225             SELF-EMPLOYED
# 260154        SPRAKERS        NY        12166          DISABLED VETERAN
# 260544        SPRAKERS        NY        12166          DISABLED VETERAN
# 264154        SPRAKERS        NY      12166.0          DISABLED VETERAN
# 289927          EUGENE        OR  974053654.0                  DISABLED
# 379163          GROTON        CT     63403740            NOT APPLICABLE
# 379537          GROTON        CT         6340                      NONE
# 379555          GROTON        CT         6340                      NONE
# 396211          BENTON        KY    420256409                      NONE
# 408043       CHARLOTTE        NC    282780039                      NONE
# 408743       VANCEBORO        NC    285869103                      NONE
# 419163   DIAMOND POINT        NY    128243010          DISABLED VETERAN
# 420332      MIDDLETOWN        OH    450444916  DEPT OF VETERANS AFFAIRS
# 420517      MIDDLETOWN        OH    450444916  DEPT OF VETERANS AFFAIRS
# 421427      MIDDLETOWN        OH    450444916  DEPT OF VETERANS AFFAIRS
# 421429        COLUMBUS        OH        43212             SELF EMPLOYED
# 421535      MIDDLETOWN        OH    450444916  DEPT OF VETERANS AFFAIRS
# 421621        COLUMBUS        OH        43212             SELF EMPLOYED
# 421741        COLUMBUS        OH        43212             SELF EMPLOYED
# 421754        COLUMBUS        OH        43212             SELF EMPLOYED
# 421839        COLUMBUS        OH        43212             SELF EMPLOYED
# 421895      MIDDLETOWN        OH    450444916  DEPT OF VETERANS AFFAIRS
# 429191    MYRTLE BEACH        SC    295793133          DISABLED VETERAN
# 430649    MURFREESBORO        TN    371304204                   US ARMY
# 431049    MURFREESBORO        TN    371304204                   US ARMY
# 435011       HENRIETTA        TX        76365                   US ARMY
# 446880       BREMERTON        WA    983124333                   VA/SSDI
# 453659       MANSFIELD        MO        65704               NOT PROVIDE
# 453660       MANSFIELD        MO        65704               NOT PROVIDE
# 453661       MANSFIELD        MO        65704               NOT PROVIDE
# 459440       YELLVILLE        AR    726878060                        VA
# 459447       YELLVILLE        AR    726878060                        VA
# 464508       GROVETOWN        GA    308134105                      NONE
#
#        contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 149790  DISABLED VETERAN              10.00        2012-1-17  NOT PROVIDE
# 150910  DISABLED VETERAN              20.00        2012-1-01  NOT PROVIDE
# 174041  DISABLED VETERAN              50.00       2011-12-02  NOT PROVIDE
# 175244  DISABLED VETERAN             250.00       2011-10-12  NOT PROVIDE
# 183790  DISABLED VETERAN             100.00       2011-10-12  NOT PROVIDE
# 184211  DISABLED VETERAN             100.00        2011-8-04  NOT PROVIDE
# 184417  DISABLED VETERAN             100.00        2011-8-23  NOT PROVIDE
# 184761  DISABLED VETERAN             110.00        2011-8-12  NOT PROVIDE
# 185140  DISABLED VETERAN              85.00        2011-7-08  NOT PROVIDE
# 185264  DISABLED VETERAN             100.00        2011-7-08  NOT PROVIDE
# 186026  DISABLED VETERAN              25.00       2011-12-16  NOT PROVIDE
# 186361  DISABLED VETERAN              25.00        2012-1-16  NOT PROVIDE
# 194750  DISABLED VETERAN             250.00       2011-11-07  NOT PROVIDE
# 205094  DISABLED VETERAN             240.00        2011-9-26  NOT PROVIDE
# 210809  DISABLED VETERAN             160.00        2011-4-27  NOT PROVIDE
# 210810  DISABLED VETERAN             160.00        2011-6-23  NOT PROVIDE
# 210811  DISABLED VETERAN             240.00        2011-9-26  NOT PROVIDE
# 225948  DISABLED VETERAN             115.00        2012-1-03  NOT PROVIDE
# 225954  DISABLED VETERAN              80.00        2012-1-10  NOT PROVIDE
# 231074  DISABLED VETERAN              60.00        2012-1-23  NOT PROVIDE
# 231773  DISABLED VETERAN              40.00       2011-10-21  NOT PROVIDE
# 232434  DISABLED VETERAN              60.00       2011-12-15  NOT PROVIDE
# 233434  DISABLED VETERAN              40.00       2011-11-23  NOT PROVIDE
# 235014  DISABLED VETERAN              50.00        2011-7-22  NOT PROVIDE
# 235112  DISABLED VETERAN              40.00        2011-9-27  NOT PROVIDE
# 235135  DISABLED VETERAN               5.00        2011-9-30  NOT PROVIDE
# 235846  DISABLED VETERAN              40.00        2011-8-24  NOT PROVIDE
# 244060  DISABLED VETERAN             500.00       2011-10-13  NOT PROVIDE
# 260154  DISABLED VETERAN              50.00        2011-7-28  NOT PROVIDE
# 260544  DISABLED VETERAN              50.00        2011-8-28  NOT PROVIDE
# 264154  DISABLED VETERAN              50.00        2011-9-28  NOT PROVIDE
# 289927  DISABLED VETERAN            1000.00        2011-9-20  NOT PROVIDE
# 379163  DISABLED VETERAN             400.00        2011-8-20  NOT PROVIDE
# 379537  DISABLED VETERAN             250.00       2011-10-19  NOT PROVIDE
# 379555  DISABLED VETERAN             201.20        2012-1-06  NOT PROVIDE
# 396211  DISABLED VETERAN             201.20        2011-6-05  NOT PROVIDE
# 408043  DISABLED VETERAN              85.82        2011-9-23  NOT PROVIDE
# 408743  DISABLED VETERAN              50.00       2011-12-17  NOT PROVIDE
# 419163  DISABLED VETERAN              47.50       2011-12-16  NOT PROVIDE
# 420332  DISABLED VETERAN              20.12        2011-7-19  NOT PROVIDE
# 420517  DISABLED VETERAN              50.00        2011-8-19  NOT PROVIDE
# 421427  DISABLED VETERAN              20.12       2011-10-19  NOT PROVIDE
# 421429  DISABLED VETERAN              25.00        2012-1-25  NOT PROVIDE
# 421535  DISABLED VETERAN              50.00       2011-12-16  NOT PROVIDE
# 421621  DISABLED VETERAN              50.00        2012-1-17  NOT PROVIDE
# 421741  DISABLED VETERAN              50.00        2012-1-16  NOT PROVIDE
# 421754  DISABLED VETERAN              25.00        2012-1-22  NOT PROVIDE
# 421839  DISABLED VETERAN              50.00        2012-1-20  NOT PROVIDE
# 421895  DISABLED VETERAN              20.12        2012-1-14  NOT PROVIDE
# 429191  DISABLED VETERAN             100.00       2011-10-19  NOT PROVIDE
# 430649  DISABLED VETERAN              61.84       2011-11-13  NOT PROVIDE
# 431049  DISABLED VETERAN              17.57       2011-12-16  NOT PROVIDE
# 435011  DISABLED VETERAN             150.00        2012-1-04  NOT PROVIDE
# 446880  DISABLED VETERAN             500.00        2011-9-13  NOT PROVIDE
# 453659  DISABLED VETERAN             100.00       2011-10-27  NOT PROVIDE
# 453660  DISABLED VETERAN              50.00       2011-11-08  NOT PROVIDE
# 453661  DISABLED VETERAN             100.00       2011-12-20  NOT PROVIDE
# 459440  DISABLED VETERAN             100.00       2011-10-20  NOT PROVIDE
# 459447  DISABLED VETERAN             100.00       2011-11-07  NOT PROVIDE
# 464508  DISABLED VETERAN             100.00        2011-6-18  NOT PROVIDE
#
#             memo_cd                  memo_text form_tp  file_num       party
# 149790  NOT PROVIDE                NOT PROVIDE   SA17A    766535    Democrat
# 150910  NOT PROVIDE                NOT PROVIDE   SA17A    766535    Democrat
# 174041  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 175244  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 183790  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 184211  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 184417  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 184761            X  * OBAMA VICTORY FUND 2012    SA18    756218    Democrat
# 185140  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 185264  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 186026  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 186361  NOT PROVIDE                NOT PROVIDE   SA17A    766535    Democrat
# 194750  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 205094  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 210809            X        BEST EFFORTS UPDATE   SA17A    763233    Democrat
# 210810            X        BEST EFFORTS UPDATE   SA17A    763233    Democrat
# 210811            X        BEST EFFORTS UPDATE   SA17A    763233    Democrat
# 225948            X  * OBAMA VICTORY FUND 2012    SA18    766535    Democrat
# 225954            X  * OBAMA VICTORY FUND 2012    SA18    766535    Democrat
# 231074  NOT PROVIDE                NOT PROVIDE   SA17A    766535    Democrat
# 231773  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 232434  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 233434  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 235014  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 235112  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 235135  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 235846  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 244060  NOT PROVIDE                NOT PROVIDE   SA17A    763233    Democrat
# 260154  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 260544  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 264154  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 289927  NOT PROVIDE                NOT PROVIDE   SA17A    756218    Democrat
# 379163  NOT PROVIDE                NOT PROVIDE   SA17A    763173  Republican
# 379537  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 379555  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 396211  NOT PROVIDE                NOT PROVIDE   SA17A    762896  Republican
# 408043  NOT PROVIDE                NOT PROVIDE   SA17A    763173  Republican
# 408743  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 419163  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 420332  NOT PROVIDE                NOT PROVIDE   SA17A    763173  Republican
# 420517  NOT PROVIDE                NOT PROVIDE   SA17A    763173  Republican
# 421427  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 421429  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 421535  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 421621  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 421741  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 421754  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 421839  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 421895  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 429191  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 430649  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 431049  NOT PROVIDE                NOT PROVIDE   SA17A    767168  Republican
# 435011  NOT PROVIDE                NOT PROVIDE   SA17A    767180  Republican
# 446880  NOT PROVIDE                NOT PROVIDE   SA17A    763173  Republican
# 453659  NOT PROVIDE                NOT PROVIDE   SA17A    763255  Republican
# 453660  NOT PROVIDE                NOT PROVIDE   SA17A    763255  Republican
# 453661  NOT PROVIDE                NOT PROVIDE   SA17A    763255  Republican
# 459440  NOT PROVIDE                NOT PROVIDE   SA17A    763621  Republican
# 459447  NOT PROVIDE                NOT PROVIDE   SA17A    763621  Republican
# 464508  NOT PROVIDE                NOT PROVIDE   SA17A    755790  Republican

# %%
# 统计各个候选人收到的政治献金总数
df_old.groupby(by=["cand_nm"])["contb_receipt_amt"].sum().sort_values(ascending=False)
# Out:
# cand_nm
# Obama, Barack     4205.00
# Paul, Ron         2425.49
# Cain, Herman       300.00
# Santorum, Rick     250.00
# Name: contb_receipt_amt, dtype: float64
